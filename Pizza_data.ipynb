# %%
import pandas as pd;
import os
import pymysql
import sqlalchemy
from sqlalchemy import create_engine, types

# %%
df = pd.read_csv('pizza_sales_excel_file4.csv', sep=';', low_memory=False)
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1   01.01.15   11:38:36
# 1             2         2  classic_dlx_m         1   01.01.15   11:57:40
# 2             3         2  five_cheese_l         1   01.01.15   11:57:40
# 3             4         2    ital_supr_l         1   01.01.15   11:57:40
# 4             5         2     mexicana_m         1   01.01.15   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1   31.12.15   21:23:10
# 48616     48617     21348  four_cheese_l         1   31.12.15   21:23:10
# 48617     48618     21348   napolitana_s         1   31.12.15   21:23:10
# 48618     48619     21349     mexicana_l         1   31.12.15   22:09:54
# 48619     48620     21350      bbq_ckn_s         1   31.12.15   23:02:05
#
#       unit_price total_price pizza_size pizza_category  \
# ...

# %%
print(df.dtypes)
# Out:
# pizza_id              int64
# order_id              int64
# pizza_name_id        object
# quantity              int64
# order_date           object
# order_time           object
# unit_price           object
# total_price          object
# pizza_size           object
# pizza_category       object
# pizza_ingredients    object
# pizza_name           object
# dtype: object

# %%
df['unit_price'] = df['unit_price'].str.replace(',', '.').astype(float)

# %%
total_unit_price = df['unit_price'].sum()
print("Toplam unit_price:", total_unit_price)
# Out:
# Toplam unit_price: 801944.7000000001

# %%
print(df.dtypes)
# Out:
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price           object
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df['total_price'] = df['total_price'].str.replace(',', '.').astype(float)

# %%
total_total_price = df['total_price'].sum()
print("Toplam total_price:", total_total_price)
# Out:
# Toplam total_price: 817860.05

# %%
print(df.dtypes)
# Out:
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1   01.01.15   11:38:36
# 1             2         2  classic_dlx_m         1   01.01.15   11:57:40
# 2             3         2  five_cheese_l         1   01.01.15   11:57:40
# 3             4         2    ital_supr_l         1   01.01.15   11:57:40
# 4             5         2     mexicana_m         1   01.01.15   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1   31.12.15   21:23:10
# 48616     48617     21348  four_cheese_l         1   31.12.15   21:23:10
# 48617     48618     21348   napolitana_s         1   31.12.15   21:23:10
# 48618     48619     21349     mexicana_l         1   31.12.15   22:09:54
# 48619     48620     21350      bbq_ckn_s         1   31.12.15   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
print(df.dtypes)
# Out:
# pizza_id               int64
# order_id               int64
# pizza_name_id         object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
db_name = 'Pizza DB'
db_host = 'localhost'
db_username = 'root'
db_password = 's3719994'

# %%
try:
    conn = pymysql.connect(host=db_host,
                         port=int(3306),
                          user="root",
                          passwd=db_password,
                          db=db_name)
except:
    print(e)

# %%
if conn:
    print("success")
else:
    print("error")
# Out:
# success

# %%
# csv_file = 'pizza_sales_excel_file4.csv' 
# df = pd.read_csv(csv_file, sep=';', low_memory=False)
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1   01.01.15   11:38:36
# 1             2         2  classic_dlx_m         1   01.01.15   11:57:40
# 2             3         2  five_cheese_l         1   01.01.15   11:57:40
# 3             4         2    ital_supr_l         1   01.01.15   11:57:40
# 4             5         2     mexicana_m         1   01.01.15   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1   31.12.15   21:23:10
# 48616     48617     21348  four_cheese_l         1   31.12.15   21:23:10
# 48617     48618     21348   napolitana_s         1   31.12.15   21:23:10
# 48618     48619     21349     mexicana_l         1   31.12.15   22:09:54
# 48619     48620     21350      bbq_ckn_s         1   31.12.15   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.columns = df.columns.str.strip()

# %%
engine = create_engine(f'mysql+pymysql://{db_username}:{db_password}@{db_host}/{db_name}')

# %%
df.to_sql('Pizza_Sales', con=engine)
# Out:
# 48620
